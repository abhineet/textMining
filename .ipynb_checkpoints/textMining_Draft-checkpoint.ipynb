# %%
f = open('/home/abhineet/Desktop/textMining/train_5500_label.txt', "r")
lines = f.readlines()

f.close()

# %%
len(lines)
# Out:
# 5452

# %%
for l in lines:
    print(l.replace('\n','').split(' ',1))
# Out:
# ['DESC:manner', 'How did serfdom develop in and then leave Russia ?']
# ['ENTY:cremat', 'What films featured the character Popeye Doyle ?']
# ['DESC:manner', "How can I find a list of celebrities ' real names ?"]
# ['ENTY:animal', 'What fowl grabs the spotlight after the Chinese Year of the Monkey ?']
# ['ABBR:exp', 'What is the full form of .com ?']
# ['HUM:ind', 'What contemptible scoundrel stole the cork from my lunch ?']
# ['HUM:gr', "What team did baseball 's St. Louis Browns become ?"]
# ['HUM:title', 'What is the oldest profession ?']
# ['DESC:def', 'What are liver enzymes ?']
# ['HUM:ind', 'Name the scar-faced bounty hunter of The Old West .']
# ['NUM:date', 'When was Ozzy Osbourne born ?']
# ['DESC:reason', 'Why do heavier objects travel downhill faster ?']
# ['HUM:ind', 'Who was The Pride of the Yankees ?']
# ['HUM:ind', 'Who killed Gandhi ?']
# ['ENTY:event', 'What is considered the costliest disaster the insurance industry has ever faced ?']
# ...

# %%
import torch 
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

# %%
data = []
for l in lines:
    labelSplit = l.replace('\n','').split(' ',1)
    data.append(((labelSplit[0], [word.lower() for word in labelSplit[1].split()])))

# %%
data[1:5]
# Out:
# [('ENTY:cremat',
#   ['what', 'films', 'featured', 'the', 'character', 'popeye', 'doyle', '?']),
#  ('DESC:manner',
#   ['how',
#    'can',
#    'i',
#    'find',
#    'a',
#    'list',
#    'of',
#    'celebrities',
#    "'",
#    'real',
#    'names',
#    '?']),
#  ('ENTY:animal',
#   ['what',
#    'fowl',
#    'grabs',
#    'the',
#    'spotlight',
#    'after',
#    'the',
#    'chinese',
#    'year',
#    'of',
#    'the',
#    'monkey',
#    '?']),
#  ('ABBR:exp', ['what', 'is', 'the', 'full', 'form', 'of', '.com', '?'])]

# %%
train_data = data[:5000]
test_data = data[5001:]

# %%
stop_words = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]


data_without_stop_word = []
for k,v in data:
    words = [t for t in v if t not in stop_words]
    data_without_stop_word.append((k,words))

# %%
data_without_stop_word[1:5]
# Out:
# [('ENTY:cremat', ['films', 'featured', 'character', 'popeye', 'doyle', '?']),
#  ('DESC:manner', ['find', 'list', 'celebrities', "'", 'real', 'names', '?']),
#  ('ENTY:animal',
#   ['fowl', 'grabs', 'spotlight', 'chinese', 'year', 'monkey', '?']),
#  ('ABBR:exp', ['full', 'form', '.com', '?'])]

# %%
_labels = []
for k,v in data_without_stop_word:
    _labels.append(k)

# %%
_unique_label = list(set(_labels) )

# %%
len(_unique_label)
# Out:
# 50

# %%
_unique_label_dict = {}
for k,v in enumerate(_unique_label):
    _unique_label_dict[v] = k

# %%
_unique_label_dict
# Out:
# {'ENTY:animal': 0,
#  'LOC:city': 1,
#  'ENTY:dismed': 2,
#  'NUM:date': 3,
#  'ENTY:body': 4,
#  'ENTY:instru': 5,
#  'HUM:desc': 6,
#  'NUM:perc': 7,
#  'NUM:dist': 8,
#  'DESC:def': 9,
#  'LOC:country': 10,
#  'NUM:weight': 11,
#  'ENTY:religion': 12,
#  'ENTY:techmeth': 13,
#  'LOC:mount': 14,
#  'NUM:volsize': 15,
#  'LOC:other': 16,
#  'ENTY:symbol': 17,
#  'HUM:ind': 18,
#  'ENTY:food': 19,
#  'ENTY:sport': 20,
#  'ENTY:termeq': 21,
#  'HUM:title': 22,
#  'ENTY:event': 23,
#  'NUM:ord': 24,
#  'DESC:desc': 25,
#  'ABBR:exp': 26,
#  'ENTY:letter': 27,
#  'ENTY:currency': 28,
#  'ENTY:lang': 29,
#  'ABBR:abb': 30,
#  'NUM:speed': 31,
#  'DESC:reason': 32,
#  'NUM:code': 33,
#  'HUM:gr': 34,
#  'ENTY:other': 35,
#  'ENTY:color': 36,
#  'NUM:count': 37,
#  'ENTY:plant': 38,
#  'ENTY:cremat': 39,
#  'NUM:period': 40,
#  'ENTY:veh': 41,
#  'ENTY:product': 42,
#  'NUM:temp': 43,
#  'NUM:money': 44,
#  'LOC:state': 45,
#  'NUM:other': 46,
#  'DESC:manner': 47,
# ...

# %%
cleaned_data = []
for k,v in data_without_stop_word:
    label = _unique_label_dict[k]
    cleaned_data.append((_unique_label_dict[k],v))

# %%
cleaned_data[1:5]
# Out:
# [(39, ['films', 'featured', 'character', 'popeye', 'doyle', '?']),
#  (47, ['find', 'list', 'celebrities', "'", 'real', 'names', '?']),
#  (0, ['fowl', 'grabs', 'spotlight', 'chinese', 'year', 'monkey', '?']),
#  (26, ['full', 'form', '.com', '?'])]

# %%
def load_glove(path):
    """
    creates a dictionary mapping words to vectors from a file in glove format.
    """
    with open(path) as f:
        glove = {}
        for line in f.readlines():
            values = line.split()
            word = values[0]
            vector = np.array(values[1:], dtype='float32')
            glove[word] = vector
        return glove

# %%
def load_glove_embeddings(path, word2idx, embedding_dim=300):
    with open(path) as f:
        embeddings = np.zeros((len(word2idx), embedding_dim))
        for line in f.readlines():
            values = line.split()
            word = values[0]
            index = word2idx.get(word)
            if index:
                vector = np.array(values[1:], dtype='float32')
                embeddings[index] = vector
        return torch.from_numpy(embeddings).float()

# %%
glove = load_glove('/home/abhineet/Desktop/textMining/glove/glove.txt')

# %%
print('abc')
# Out:
# abc

# %%
corpus = 'films fowl list spotlight real names'
vocab = set(corpus.split()) # compute vocab, 6 words
word2idx = {word: idx for idx, word in enumerate(vocab)} # create word index

# %%
word2idx
# Out:
# {'films': 0, 'fowl': 1, 'real': 2, 'spotlight': 3, 'list': 4, 'names': 5}

# %%
toy_embeddings = load_glove_embeddings('/home/abhineet/Desktop/textMining/glove/glove.txt', word2idx)

# %%
toy_embeddings # 6 words x 60 embedding dimensions
toy_embeddings.size()
# Out:
# torch.Size([6, 300])

# %%
toy_embedding = nn.Embedding(toy_embeddings.size(0), toy_embeddings.size(1))
toy_embedding.weight = nn.Parameter(toy_embeddings)

# %%
toy_embedding
# Out:
# Embedding(6, 300)

# %%
toy_embedding(Variable(torch.LongTensor([2])))
# Out:
# tensor([[-4.8489e-01,  2.4163e-01, -5.0128e-01, -4.5097e-02,  3.7143e-01,
#           1.0937e-01,  3.1291e-01,  9.5234e-03,  4.7044e-01,  2.5933e+00,
#          -7.4749e-01, -7.1667e-02,  1.3045e-01, -2.2075e-01, -3.0882e-01,
#          -1.6049e-01,  2.0450e-01,  1.1824e+00, -3.6161e-01, -3.0831e-01,
#           2.4493e-01, -3.1142e-01,  5.0488e-02, -3.4382e-01, -1.1825e-01,
#          -2.5274e-02,  4.1516e-01,  2.4837e-01,  5.8501e-02,  3.5913e-01,
#           1.1271e-01,  2.3022e-01,  1.1943e-01,  1.5883e-01,  4.5396e-01,
#           1.2050e-02,  3.2591e-01,  1.5523e-01, -7.4605e-03, -4.2106e-01,
#          -1.1638e-01,  2.3663e-01,  4.5410e-01, -1.8914e-01, -5.7456e-02,
#           3.8832e-01,  4.6130e-01, -3.9910e-01,  1.9584e-01,  6.4995e-02,
#          -1.1323e-01,  4.8641e-01, -6.0098e-01,  3.0343e-01,  2.1738e-01,
#           1.1098e-01, -1.7456e-01,  1.0435e-01,  5.4206e-01, -4.1202e-01,
#          -2.1109e-01,  9.5876e-02, -4.8299e-01,  1.9545e-01,  5.2642e-01,
# ...

# %%
glove.get('#UNK#')
# Out:
# array([ 2.24186122e-01, -2.88818091e-01,  1.38543546e-01,  3.65397427e-03,
#        -1.28707692e-01,  1.02439500e-01,  6.16270304e-02,  7.31776878e-02,
#        -6.13538735e-02, -1.34764123e+00,  4.20387477e-01, -6.35957941e-02,
#        -9.68335494e-02,  1.80862889e-01,  2.37044320e-01,  1.41268317e-02,
#         1.70097291e-01, -1.14917016e+00,  3.14985871e-01,  6.62226081e-02,
#         2.46880129e-02,  7.66948611e-02,  1.38516560e-01,  2.13018917e-02,
#        -6.64063916e-02, -1.03365527e-02,  1.35231748e-01, -4.21435684e-02,
#        -1.19387127e-01,  6.94914674e-03,  1.33330137e-01, -1.82762340e-01,
#         5.23855723e-02,  8.94323085e-03, -2.39571974e-01,  8.50034729e-02,
#        -6.89418754e-03,  1.58654165e-03,  6.33913055e-02,  1.91776469e-01,
#        -1.31133288e-01, -1.12955049e-01, -1.42774358e-01,  3.41393538e-02,
#        -3.42800766e-02, -5.13660759e-02,  1.88915119e-01, -1.66733667e-01,
# ...

# %%
glove.get('popeye')

# %%
cleaned_data[1:5]
# Out:
# [(39, ['films', 'featured', 'character', 'popeye', 'doyle', '?']),
#  (47, ['find', 'list', 'celebrities', "'", 'real', 'names', '?']),
#  (0, ['fowl', 'grabs', 'spotlight', 'chinese', 'year', 'monkey', '?']),
#  (26, ['full', 'form', '.com', '?'])]

# %%
total_words_orig = []
for k,v in cleaned_data:
    for ele in v :
        total_words_orig.append(ele)

# %%
total_words = list(set(total_words_orig))

# %%
total_words_str = ' '.join(total_words)

# %%
len(total_words)
# Out:
# 8561

# %%
len(total_words_orig)
# Out:
# 33193

# %%
vocab = set(total_words_str.split()) # compute vocab, 6 words
word2idx = {word: idx for idx, word in enumerate(vocab)} # create word index

# %%
toy_embeddings = load_glove_embeddings('/home/abhineet/Desktop/textMining/glove/glove.txt', word2idx)

# %%
toy_embeddings # 6 words x 60 embedding dimensions
toy_embeddings.size()
# Out:
# torch.Size([8561, 300])

# %%
nn.Parameter(toy_embeddings)
# Out:
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         ...,
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0484, -0.1645, -0.6549,  ..., -0.3954,  0.3623, -0.1524],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#        requires_grad=True)

# %%
toy_embedding = nn.Embedding(toy_embeddings.size(0), toy_embeddings.size(1))
# toy_embedding.weight = nn.Parameter(toy_embeddings)

# %%
word2idx['rank']
# Out:
# 5

# %%
toy_embedding(Variable(torch.LongTensor([word2idx['rank']])))
# Out:
# tensor([[ 5.7686e-01, -2.2332e-01,  4.8129e-01,  2.3029e+00, -1.3995e-01,
#          -3.2111e-01, -1.5552e+00, -4.7019e-01,  6.9364e-01,  1.0838e+00,
#          -8.9944e-01, -5.6885e-01,  5.3415e-01, -1.1675e-01,  6.4118e-01,
#          -4.9232e-01, -5.4548e-01, -1.1063e+00, -5.2773e-01,  3.1848e-01,
#           8.7788e-01, -6.2035e-01,  1.5028e-01, -1.1312e+00, -4.7622e-01,
#           2.3257e-01, -5.8072e-01,  1.1508e+00, -9.4592e-01, -8.4512e-01,
#           2.2783e+00, -4.8439e-01,  2.2936e-02,  3.1454e-01, -5.2772e-01,
#          -7.1286e-01, -9.0492e-01,  9.5553e-01,  1.8313e+00, -2.4872e+00,
#          -1.5567e+00,  9.9830e-01,  2.4634e-01,  2.5099e-01, -1.4040e-01,
#           5.7784e-01,  1.6682e-01, -1.9135e+00,  2.0524e-02,  1.5047e+00,
#          -2.8855e+00, -2.0364e+00, -4.6490e-01, -2.2782e+00,  2.8277e-01,
#          -2.9247e-01, -1.0587e-01, -5.0505e-01, -6.0729e-01, -3.0307e-01,
#           1.5598e+00, -1.0631e+00, -8.2976e-01,  5.4654e-01,  3.8503e-01,
# ...

# %%
toy_embeddings[5]
# Out:
# tensor([-5.5861e-01,  1.8840e-01,  1.2008e-01, -1.1324e-01,  1.2282e-01,
#          8.7131e-02,  2.2947e-01,  2.9654e-02,  1.9988e-01,  1.7745e+00,
#         -2.0609e-01, -2.0679e-01, -2.2652e-01, -3.3421e-01,  1.8271e-01,
#          1.9245e-01, -8.5927e-02,  7.8389e-01, -3.0628e-01,  3.4641e-01,
#          2.8376e-01,  1.7186e-01, -5.9299e-02,  1.4249e-01, -1.1371e-01,
#         -9.5882e-02, -2.8296e-01, -2.2217e-01, -4.0685e-01,  1.3844e-02,
#          6.5789e-01,  3.7387e-01,  3.5555e-01,  1.8791e-01, -7.5253e-01,
#         -6.0809e-01, -1.7414e-01,  4.7658e-02,  8.9542e-02, -2.3890e-01,
#         -3.6904e-01, -2.8983e-01, -1.0259e-02,  4.3836e-01,  1.3009e+00,
#         -5.1996e-01,  3.7813e-01,  8.4507e-01, -3.0582e-01, -7.6801e-02,
#          3.3240e-01,  3.3300e-01,  4.9380e-01, -2.5341e-01, -1.8778e-01,
#          2.3881e-01,  2.6668e-01, -2.6357e-01, -1.8558e-01, -4.7654e-01,
#          8.3119e-03,  1.0681e-01,  9.7773e-02, -1.1362e-01,  3.9390e-01,
# ...

# %%
toy_embedding = nn.Embedding.from_pretrained(toy_embeddings,freeze=True)
# toy_embedding.weight = nn.Parameter(toy_embeddings)

# %%
toy_embedding(Variable(torch.LongTensor([word2idx['rank']])))
# Out:
# tensor([[-5.5861e-01,  1.8840e-01,  1.2008e-01, -1.1324e-01,  1.2282e-01,
#           8.7131e-02,  2.2947e-01,  2.9654e-02,  1.9988e-01,  1.7745e+00,
#          -2.0609e-01, -2.0679e-01, -2.2652e-01, -3.3421e-01,  1.8271e-01,
#           1.9245e-01, -8.5927e-02,  7.8389e-01, -3.0628e-01,  3.4641e-01,
#           2.8376e-01,  1.7186e-01, -5.9299e-02,  1.4249e-01, -1.1371e-01,
#          -9.5882e-02, -2.8296e-01, -2.2217e-01, -4.0685e-01,  1.3844e-02,
#           6.5789e-01,  3.7387e-01,  3.5555e-01,  1.8791e-01, -7.5253e-01,
#          -6.0809e-01, -1.7414e-01,  4.7658e-02,  8.9542e-02, -2.3890e-01,
#          -3.6904e-01, -2.8983e-01, -1.0259e-02,  4.3836e-01,  1.3009e+00,
#          -5.1996e-01,  3.7813e-01,  8.4507e-01, -3.0582e-01, -7.6801e-02,
#           3.3240e-01,  3.3300e-01,  4.9380e-01, -2.5341e-01, -1.8778e-01,
#           2.3881e-01,  2.6668e-01, -2.6357e-01, -1.8558e-01, -4.7654e-01,
#           8.3119e-03,  1.0681e-01,  9.7773e-02, -1.1362e-01,  3.9390e-01,
# ...

# %%
from collections import Counter

counts = Counter(total_words_orig)

# %%
counts.items()
# Out:
# dict_items([('serfdom', 1), ('develop', 2), ('leave', 6), ('russia', 5), ('?', 5350), ('films', 6), ('featured', 8), ('character', 33), ('popeye', 4), ('doyle', 1), ('find', 86), ('list', 10), ('celebrities', 3), ("'", 62), ('real', 15), ('names', 26), ('fowl', 1), ('grabs', 1), ('spotlight', 1), ('chinese', 10), ('year', 78), ('monkey', 3), ('full', 9), ('form', 17), ('.com', 1), ('contemptible', 3), ('scoundrel', 3), ('stole', 5), ('cork', 4), ('lunch', 3), ('team', 33), ('baseball', 33), ("'s", 720), ('st.', 14), ('louis', 5), ('browns', 2), ('become', 27), ('oldest', 12), ('profession', 5), ('liver', 2), ('enzymes', 1), ('name', 330), ('scar-faced', 1), ('bounty', 4), ('hunter', 4), ('old', 35), ('west', 19), ('.', 105), ('ozzy', 1), ('osbourne', 1), ('born', 30), ('heavier', 2), ('objects', 3), ('travel', 12), ('downhill', 1), ('faster', 1), ('pride', 2), ('yankees', 3), ('killed', 23), ('gandhi', 4), ('considered', 8), ('costliest', 1), ('disaster', 1), ('insurance', 4), ('indu
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotib inline
# %pylab inline

labels, values = zip(*counts.items())

indexes = np.arange(len(labels))
width = 1

plt.bar(indexes, values, width)
plt.xticks(indexes + width * 0.5, labels)
plt.show()

# %%
counts_2 = {x : counts[x] for x in counts if counts[x] >= 2}

# %%
len(counts_2)
# Out:
# 3367

# %%
len(counts)
# Out:
# 8561

# %%
words_random = []

# %%
for k,v in counts_2.items():
    words_random.append(k)

# %%
len(words_random)
# Out:
# 3367

# %%
word2idxrandom = {word: idx for idx, word in enumerate(words_random)}

# %%
toy_embeddings = load_glove_embeddings('/home/abhineet/Desktop/textMining/glove/glove.txt', word2idxrandom)

# %%
toy_embeddings # 6 words x 60 embedding dimensions
toy_embeddings.size()
toy_embedding = nn.Embedding(toy_embeddings.size(0), toy_embeddings.size(1))
toy_embedding(Variable(torch.LongTensor([word2idxrandom['rank']])))
# Out:
# tensor([[ 7.2200e-01,  8.4311e-01,  3.2101e+00,  1.5265e-01,  8.2975e-01,
#          -2.8163e-01, -3.5416e-01,  8.0883e-01,  1.3693e+00,  1.3402e+00,
#           9.2080e-01, -1.7036e-01, -1.4289e+00, -2.6013e-01, -1.0829e+00,
#           1.0307e+00, -9.3508e-01, -8.4978e-01, -3.6045e-01,  6.9029e-01,
#          -1.9593e+00,  8.6225e-01, -1.5594e+00, -1.5022e+00, -2.5490e-01,
#           7.1469e-01,  3.3184e-01,  1.9860e-01,  1.2192e+00,  8.9156e-01,
#           1.4064e-01, -9.9555e-01,  1.0377e+00, -9.0037e-01, -7.7850e-01,
#          -1.3523e+00,  1.3754e+00,  5.6646e-01,  1.2769e+00,  5.5512e-01,
#           1.8699e-01,  5.7729e-01,  1.7690e-01,  1.5094e+00, -1.3231e+00,
#          -1.7873e-01, -2.2805e-01, -8.2308e-01,  8.8393e-01,  1.0501e+00,
#          -9.4197e-01, -4.2439e-01,  7.0121e-01, -6.5256e-01, -1.5944e+00,
#          -2.8105e-01, -4.3765e-02,  8.0043e-02,  3.9246e-01,  5.1389e-01,
#           6.8367e-01,  2.0628e+00, -7.8540e-01, -8.2034e-01, -3.4572e-02,
# ...

# %%
word2idxrandom['rank']
# Out:
# 2019

# %%
toy_embeddings[2019]
# Out:
# tensor([-5.5861e-01,  1.8840e-01,  1.2008e-01, -1.1324e-01,  1.2282e-01,
#          8.7131e-02,  2.2947e-01,  2.9654e-02,  1.9988e-01,  1.7745e+00,
#         -2.0609e-01, -2.0679e-01, -2.2652e-01, -3.3421e-01,  1.8271e-01,
#          1.9245e-01, -8.5927e-02,  7.8389e-01, -3.0628e-01,  3.4641e-01,
#          2.8376e-01,  1.7186e-01, -5.9299e-02,  1.4249e-01, -1.1371e-01,
#         -9.5882e-02, -2.8296e-01, -2.2217e-01, -4.0685e-01,  1.3844e-02,
#          6.5789e-01,  3.7387e-01,  3.5555e-01,  1.8791e-01, -7.5253e-01,
#         -6.0809e-01, -1.7414e-01,  4.7658e-02,  8.9542e-02, -2.3890e-01,
#         -3.6904e-01, -2.8983e-01, -1.0259e-02,  4.3836e-01,  1.3009e+00,
#         -5.1996e-01,  3.7813e-01,  8.4507e-01, -3.0582e-01, -7.6801e-02,
#          3.3240e-01,  3.3300e-01,  4.9380e-01, -2.5341e-01, -1.8778e-01,
#          2.3881e-01,  2.6668e-01, -2.6357e-01, -1.8558e-01, -4.7654e-01,
#          8.3119e-03,  1.0681e-01,  9.7773e-02, -1.1362e-01,  3.9390e-01,
# ...

# %%
labels = {}
for i in range(0, 50): 
    label = [0] * 50
    label[i] = 1
    labels[i] = label
    
cleaned_data_final = []
for data in cleaned_data:
    cleaned_data_final.append([labels[data[0]], data[1]])
